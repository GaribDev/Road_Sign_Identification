# %%
#Libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from tensorflow.keras.models  import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout, Flatten, Conv2D, MaxPooling2D
import pickle
import random
import pandas as pd
#for plot theme
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 200
from jupyterthemes import jtplot
jtplot.style(theme='monokai')

# %%
# !git clone https://bitbucket.org/jadslim/german-traffic-signs

# %%
with open('german-traffic-signs/train.p','rb') as f:
    train_data = pickle.load(f)
with open('german-traffic-signs/valid.p','rb') as f:
    val_data = pickle.load(f)

# %%
X_train, y_train = train_data['features'], train_data['labels']
X_val, y_val = val_data['features'], val_data['labels']
print(X_train.shape)
print(X_val.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)

# %%
assert(X_train.shape[0] == y_train.shape[0]), "The number of images is not equal to the number of labels"
assert(X_val.shape[0] == y_val.shape[0]), "The number of images is not equal to the number of labels"
assert(X_train.shape[1:] == (32, 32, 3)), "The dimensions of the image is not 32*32*3"
assert(X_val.shape[1:] == (32, 32, 3)), "The dimensions of the image is not 32*32*3"

# %% [markdown]
# # Data Viz

# %%
data = pd.read_csv('german-traffic-signs/signnames.csv')
num_of_samples = []
cols = 5
num_classes = 43

fig, axs = plt.subplots(nrows = num_classes, ncols = cols, figsize = (5, 50))
fig.tight_layout()

for i in range(cols):
    for j, row in data.iterrows():
        x_selected = X_train[y_train == j]
        axs[j][i].imshow(x_selected[random.randint(0, (len(x_selected)-1)), :, :], cmap = plt.get_cmap("gray"))
        axs[j][i].axis("off")
        if i == 2:
            axs[j][i].set_title(str(j) + "_" + row["SignName"])
            num_of_samples.append(len(x_selected))

# %%
print(num_of_samples)
plt.figure(figsize = (12, 4))
plt.bar(range(0, num_classes), num_of_samples)
plt.title("Training Dataset Distribution")
plt.xlabel("Class number")
plt.ylabel("Number of images")
# Out:
# [180, 1980, 2010, 1260, 1770, 1650, 360, 1290, 1260, 1320, 1800, 1170, 1890, 1920, 690, 540, 360, 990, 1080, 180, 300, 270, 330, 450, 240, 1350, 540, 210, 480, 240, 390, 690, 210, 599, 360, 1080, 330, 180, 1860, 270, 300, 210, 210]
# Text(0, 0.5, 'Number of images')

# %% [markdown]
# # Data pre-processing

# %%
plt.imshow(X_train[1000])
plt.axis('off')
print(X_train[1000].shape)
print(y_train[1000])
# Out:
# (32, 32, 3)
# 36

# %%
def grayscale(img):
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    plt.axis('off')
    return image
img = grayscale(X_train[1000])
plt.imshow(img, cmap = 'gray')
print(img.shape)
# Out:
# (32, 32)

# %%
def equalize(img):
    img = cv2.equalizeHist(img)
    return img
img = equalize(img)
plt.imshow(img, cmap = 'gray')
plt.axis('off')
print(img.shape)
# Out:
# (32, 32)

# %%
def preprocessing(img):
    img = grayscale(img)
    img = equalize(img)
    img = img/255
    return img

# %%
X_train = np.asarray(list(map(preprocessing, X_train)))
X_val = np.asarray(list(map(preprocessing, X_val)))

# %%
X_train = X_train.reshape(34799, 32, 32, 1)
X_val = X_val.reshape(4410, 32, 32, 1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(width_shift_range = 0.1,
                  height_shift_range = 0.1,
                  zoom_range = 0.2,
                  shear_range = 0.1,
                  rotation_range = 10)
datagen.fit(X_train)

# %%
batches = datagen.flow(X_train, y_train, batch_size = 20)
X_batch, y_batch = next(batches)

fig, axs = plt.subplots(1, 15, figsize = (40, 5))
fig.tight_layout()

for i in range(15):
  axs[i].imshow(X_batch[i].reshape(32,32))
  axs[i].axis('off')

# %%
y_train = to_categorical(y_train, 43)
y_val = to_categorical(y_val, 43)

# %% [markdown]
# # Neural Network

# %%
def neural_model():
    model = Sequential()
    model.add(Conv2D(60, (5, 5), input_shape = (32, 32, 1), activation = 'relu'))
    model.add(Conv2D(60, (5, 5), input_shape = (32, 32, 1), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Conv2D(30, (3, 3), activation = 'relu'))
    model.add(Conv2D(30, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    
    #model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(500, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation = 'softmax'))
    model.compile(Adam(lr = 0.001),loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ['accuracy'])
    return model

# %%
model = neural_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 60)        1560
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 60)        90060
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 60)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 30)        16230
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 30)          8130
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 480)               0
# _________________________________________________________________
# dense (Dense)                (None, 500)               240500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                21543
# =================================================================
# Total params: 378,023
# Trainable params: 378,023
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 50), steps_per_epoch = 200, epochs = 100, validation_data =(X_val, y_val), shuffle = 1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 200 steps, validate on 4410 samples
# Epoch 1/100
# 200/200 [==============================] - 5s 24ms/step - loss: 2.0505 - accuracy: 0.4164 - val_loss: 0.8422 - val_accuracy: 0.7417
# Epoch 2/100
# 200/200 [==============================] - 5s 24ms/step - loss: 1.1716 - accuracy: 0.6499 - val_loss: 0.4229 - val_accuracy: 0.8814
# Epoch 3/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.7782 - accuracy: 0.7626 - val_loss: 0.2551 - val_accuracy: 0.9195
# Epoch 4/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.5868 - accuracy: 0.8237 - val_loss: 0.1972 - val_accuracy: 0.9351
# Epoch 5/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.4928 - accuracy: 0.8458 - val_loss: 0.1310 - val_accuracy: 0.9599
# Epoch 6/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.4091 - accuracy: 0.8751 - val_loss: 0.1264 - val_accuracy: 0.9562
# Epoch 7/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.3752 - accuracy: 0.8859 - val_loss: 0.1054 - val_accuracy: 0.9680
# Epoch 8/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.3225 - accuracy: 0.8968 - val_loss: 0.1641 - val_accuracy: 0.9531
# Epoch 9/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.2946 - accuracy: 0.9084 - val_loss: 0.0642 - val_accuracy: 0.9828
# Epoch 10/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.2602 - accuracy: 0.9199 - val_loss: 0.0847 - val_accuracy: 0.9760
# Epoch 11/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.2499 - accuracy: 0.9211 - val_loss: 0.0744 - val_accuracy: 0.9810
# Epoch 12/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.2279 - accuracy: 0.9280 - val_loss: 0.0699 - val_accuracy: 0.9800
# Epoch 13/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.2188 - accuracy: 0.9330 - val_loss: 0.0937 - val_accuracy: 0.9707
# Epoch 14/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.1972 - accuracy: 0.9366 - val_loss: 0.0785 - val_accuracy: 0.9782
# Epoch 15/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0
100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0862 - accuracy: 0.9743 - val_loss: 0.0371 - val_accuracy: 0.9882
# Epoch 45/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0914 - accuracy: 0.9709 - val_loss: 0.0426 - val_accuracy: 0.9884
# Epoch 46/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0957 - accuracy: 0.9701 - val_loss: 0.0455 - val_accuracy: 0.9859
# Epoch 47/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0888 - accuracy: 0.9725 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 48/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0861 - accuracy: 0.9731 - val_loss: 0.0336 - val_accuracy: 0.9887
# Epoch 49/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0892 - accuracy: 0.9716 - val_loss: 0.0281 - val_accuracy: 0.9921
# Epoch 50/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0832 - accuracy: 0.9747 - val_loss: 0.0495 - val_accuracy: 0.9855
# Epoch 51/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0888 - accuracy: 0.9725 - val_loss: 0.0254 - val_accuracy: 0.9941
# Epoch 52/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0784 - accuracy: 0.9733 - val_loss: 0.0382 - val_accuracy: 0.9902
# Epoch 53/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0777 - accuracy: 0.9741 - val_loss: 0.0344 - val_accuracy: 0.9884
# Epoch 54/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0771 - accuracy: 0.9767 - val_loss: 0.0709 - val_accuracy: 0.9832
# Epoch 55/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0742 - accuracy: 0.9774 - val_loss: 0.0488 - val_accuracy: 0.9868
# Epoch 56/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0727 - accuracy: 0.9769 - val_loss: 0.0782 - val_accuracy: 0.9819
# Epoch 57/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0798 - accuracy: 0.9767 - val_loss: 0.0386 - val_accuracy: 0.9887
# Epoch 58/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0747 - accuracy: 0.9782 - val_loss: 0.0641 - val_accuracy: 0.9830
# Epoch 59/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0703 - accuracy: 0.9788 - val_loss: 0.0388 - val_accuracy: 0.9896
# Epoch 60/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0739 - accuracy: 0.9784 - val_loss: 0.0356 - val_accuracy: 0.9900
# Epoch 61/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0725 - accuracy: 0.9778 - val_loss: 0.0427 - val_accuracy: 0.9889
# Epoch 62/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0815 - accuracy: 0.9737 - val_loss: 0.0213 - val_accuracy: 0.9948
# Epoch 63/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0667 - accuracy: 0.9805 - val_loss: 0.0286 - val_accuracy: 0.9923
# Epoch 64/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0606 - accuracy: 0.9829 - val_loss: 0.0255 - val_accuracy: 0.9930
# Epoch 65/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0673 - accuracy: 0.9793 - val_loss: 0.0350 - val_accuracy: 0.9909
# Epoch 66/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0741 - accuracy: 0.9791 - val_loss: 0.0418 - val_accuracy: 0.9882
# Epoch 67/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0641 - accuracy: 0.9804 - val_loss: 0.0386 - val_accuracy: 0.9893
# Epoch 68/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0799 - accuracy: 0.9756 - val_loss: 0.0307 - val_accuracy: 0.9898
# Epoch 69/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0756 - accuracy: 0.9770 - val_loss: 0.0361 - val_accuracy: 0.9884
# Epoch 70/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0732 - accuracy: 0.9778 - val_loss: 0.0375 - val_accuracy: 0.9902
# Epoch 71/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 0.0383 - val_accuracy: 0.9896
# Epoch 72/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0665 - accuracy: 0.9813 - val_loss: 0.0315 - val_accuracy: 0.9914
# Epoch 73/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0609 - accuracy: 0.9810 - val_loss: 0.0298 - val_accuracy: 0.9914
# Epoch 74/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0618 - accuracy: 0.9810 - val_loss: 0.0368 - val_accuracy: 0.9898
# Epoch 75/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.0272 - val_accuracy: 0.9923
# Epoch 76/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0638 - accuracy: 0.9803 - val_loss: 0.0590 - val_accuracy: 0.9871
# Epoch 77/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0667 - accuracy: 0.9788 - val_loss: 0.0600 - val_accuracy: 0.9828
# Epoch 78/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0586 - accuracy: 0.9820 - val_loss: 0.0611 - val_accuracy: 0.9857
# Epoch 79/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0629 - accuracy: 0.9814 - val_loss: 0.0754 - val_accuracy: 0.9893
# Epoch 80/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0632 - accuracy: 0.9819 - val_loss: 0.0563 - val_accuracy: 0.9887
# Epoch 81/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0606 - accuracy: 0.9822 - val_loss: 0.0506 - val_accuracy: 0.9866
# Epoch 82/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0781 - accuracy: 0.9772 - val_loss: 0.1115 - val_accuracy: 0.9878
# Epoch 83/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0533 - accuracy: 0.9859 - val_loss: 0.1141 - val_accuracy: 0.9866
# Epoch 84/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0631 - accuracy: 0.9829 - val_loss: 0.0462 - val_accuracy: 0.9912
# Epoch 85/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0767 - accuracy: 0.9779 - val_loss: 0.0434 - val_accuracy: 0.9889
# Epoch 86/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0690 - accuracy: 0.9808 - val_loss: 0.0211 - val_accuracy: 0.9950
# Epoch 87/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0693 - accuracy: 0.9805 - val_loss: 0.0408 - val_accuracy: 0.9878
# Epoch 88/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0595 - accuracy: 0.9811 - val_loss: 0.0436 - val_accuracy: 0.9880
# Epoch 89/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0650 - accuracy: 0.9804 - val_loss: 0.0381 - val_accuracy: 0.9914
# Epoch 90/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0559 - accuracy: 0.9831 - val_loss: 0.0318 - val_accuracy: 0.9918
# Epoch 91/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 0.0438 - val_accuracy: 0.9900
# Epoch 92/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0590 - accuracy: 0.9819 - val_loss: 0.0280 - val_accuracy: 0.9930
# Epoch 93/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0560 - accuracy: 0.9830 - val_loss: 0.0250 - val_accuracy: 0.9925
# Epoch 94/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0574 - accuracy: 0.9822 - val_loss: 0.0401 - val_accuracy: 0.9905
# Epoch 95/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0612 - accuracy: 0.9827 - val_loss: 0.0901 - val_accuracy: 0.9841
# Epoch 96/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0543 - accuracy: 0.9836 - val_loss: 0.0515 - val_accuracy: 0.9875
# Epoch 97/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0631 - accuracy: 0.9798 - val_loss: 0.0583 - val_accuracy: 0.9889
# Epoch 98/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0588 - accuracy: 0.9832 - val_loss: 0.0559 - val_accuracy: 0.9864
# Epoch 99/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0559 - accuracy: 0.9822 - val_loss: 0.0441 - val_accuracy: 0.9884
# Epoch 100/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0616 - accuracy: 0.9810 - val_loss: 0.0474 - val_accuracy: 0.9878

# %%
model.save('trained_model.h5')

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['loss', 'val_loss', 'accuracy', 'val_acc'])
plt.title('Loss & Accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')
